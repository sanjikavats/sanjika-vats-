# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\lab-pc\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lab-pc\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lab-pc\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab-pc\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab-pc\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lab-pc\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd

# %%
data={
    'singer':['Mohammed Rafi','neha kakkar','tony kakkar','Arijit Singh','Sonu Nigam'],'Active Year':[25,45,85,69,39],'Number_of_Songs':[750,900,1293,594,682],'Awards_Won':[69,83,189,55,49]}

# %%
singers_df = pd.DataFrame(data)

# %%
singers_df
# Out:
#           singer  Active Year  Number_of_Songs  Awards_Won
# 0  Mohammed Rafi           25              750          69
# 1    neha kakkar           45              900          83
# 2    tony kakkar           85             1293         189
# 3   Arijit Singh           69              594          55
# 4     Sonu Nigam           39              682          49

# %% [raw]
# singers_df.info()

# %%
singers_df.describe()
# Out:
#        Active Year  Number_of_Songs  Awards_Won
# count     5.000000         5.000000    5.000000
# mean     52.600000       843.800000   89.000000
# std      24.099793       274.916715   57.428216
# min      25.000000       594.000000   49.000000
# 25%      39.000000       682.000000   55.000000
# 50%      45.000000       750.000000   69.000000
# 75%      69.000000       900.000000   83.000000
# max      85.000000      1293.000000  189.000000

# %%
max_songs = singers_df['Number_of_Songs'].max()
min_songs = singers_df['Number_of_Songs'].min()
mean_awards = singers_df['Awards_Won'].mean()
median_years = singers_df['Active Year'].median()
print(f"Maximun number of songs: {max_songs}")
print(f"Minimun number of songs: {min_songs}")
print(f"Average awards won: {mean_awards:.2f}")
print(f"Median years active: {median_years}")
# Out:
# Maximun number of songs: 1293
# Minimun number of songs: 594
# Average awards won: 89.00
# Median years active: 45.0

# %%
sorted_singers = singers_df.sort_values(by='Awards_Won',ascending=False)
sorted_singers
# Out:
#           singer  Active Year  Number_of_Songs  Awards_Won
# 2    tony kakkar           85             1293         189
# 1    neha kakkar           45              900          83
# 0  Mohammed Rafi           25              750          69
# 3   Arijit Singh           69              594          55
# 4     Sonu Nigam           39              682          49

# %%
singers_with_many_awards=singers_df[singers_df['Awards_Won']>50]
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,5))
plt.bar(singers_df['singer'], singers_df['Number_of_Songs'], color='violet')
plt.title('Number of Songs by Indian Singers')
plt.xlabel('Singer')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
