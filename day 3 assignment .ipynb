# %%
# !pip install opencv.python
# Out:
# Requirement already satisfied: opencv.python in c:\users\hp\anaconda\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in c:\users\hp\anaconda\lib\site-packages (from opencv.python) (2.3.5)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
img = cv2.imread("scene.jpg")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img_resized = cv2.resize(img,(500,300))
plt.imshow(img_resized)
plt.show()

# %%
cv2.imshow("scene.jpg",img)
cv2.waitKey(0)

# %%
img_flip=cv2.flip(img,0)
cv2.imshow("scene.jpg",img_flip)
cv2.waitKey(0)
